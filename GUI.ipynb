# %%
from tkinter import *
import joblib
import numpy as np
import pymongo
from PIL import ImageTk,Image

# %%
import pandas as pd
df1= pd.read_csv("Final_dataset.csv")
df=df1.describe()

# %%
def calculate():
   
    def mySubmit():
        
        def Update():

            client = pymongo.MongoClient("mongodb://rk:Test12345@cluster0-shard-00-00.s0mpm.mongodb.net:27017,cluster0-shard-00-01.s0mpm.mongodb.net:27017,cluster0-shard-00-02.s0mpm.mongodb.net:27017/Sample?ssl=true&replicaSet=atlas-elkw9m-shard-0&authSource=admin&retryWrites=true&w=majority")
            db = client.test
            print(db)
            #client = pymongo.MongoClient(connection_url)
  
            # # Database
            Database = client.get_database('Sample')
            # # Table
            SampleTable1 = Database.pred
            SampleTable1.insert_one({'Risk weight': prediction[-1],'Masks' : masks, "sanitizers" : sanitizers, 'Vaccines':Vaccines,'Oxygen':Oxygen,'PPE':PPE})
        
        def des():
            root1.destroy()
        
        root1 = Tk()
        root1.geometry("520x330")
        root1.title("Resources released")
        root1.configure(bg='#17202A')
        a=[v1.get(),v2.get(),v3.get(),v4.get(),v5.get(),
        v6.get(),v7.get(),v8.get(),v9.get(),v10.get(),
        v11.get(),v12.get(),v13.get(),v14.get(),v15.get(),
        v16.get(),v17.get()]
     
        b = [float(x) for x in a]
    
        items=[]
        for item in df:
            items.append(item)

        test=[]
        for i in range(0,17):
            c = (b[i]-df[items[i]][1])/(df[items[i]][2])
            test.append(c)
    
        x = np.expand_dims(test, axis = 0) 

        model = joblib.load("random_forest_final.joblib")
    
        pred=model.predict(x)
        print(pred[0])
        prediction = "The risk weight level is : "+ str(pred[0])
        
        masks =sanitizers=Vaccines=Oxygen= PPE=0
        
        if pred[0]==0:
            masks="1,000,000"
            sanitizers="200,000"
            Vaccines="200,000"
            Oxygen="4,000"
            PPE="100,000"
        if pred[0]==1:
            masks="1,500,000"
            sanitizers="500,000"
            Vaccines="150,000"
            Oxygen="7,000"
            PPE="300,000"
        if pred[0]==2:
            masks="3,000,000"
            sanitizers="900,000"
            Vaccines="300,000"
            Oxygen="9,000"
            PPE="600,000"
        
        my_label = Label(root1, text = prediction,padx=20,fg='white',bg='#696969')
        my_label.grid(row = 0 , column = 0,columnspan= 2 ,pady=10,padx=60)
        label2 = Label(root1, text = "Recommended Resources : ",padx=13,fg='white',bg='#696969')
        label2.grid(row = 2, column = 0, columnspan= 2 ,pady=10)
        label3 = Label(root1, text="Masks",padx=70,fg='white',bg='#696969')
        label4 = Label(root1, text="Sanitizers",padx=63,fg='white',bg='#696969')
        label5 = Label(root1, text="Vaccines",padx=65,fg='white',bg='#696969')
        label6 = Label(root1, text="Oxygen Cylinders",padx=43,fg='white',bg='#696969')
        label7 = Label(root1, text="PPE kits",padx=69,fg='white',bg='#696969')

        label8 = Label(root1,text=masks,padx=60,fg='white',bg='#696969')
        label9 = Label(root1, text=sanitizers,padx=65,fg='white',bg='#696969')
        label10 = Label(root1, text=Vaccines,padx=65,fg='white',bg='#696969')
        label11 = Label(root1, text=Oxygen,padx=70,fg='white',bg='#696969')
        label12 = Label(root1, text=PPE,padx=65,fg='white',bg='#696969')
        
        
        label3.grid(row = 3, column = 0, columnspan= 2 ,pady=10)
        label4.grid(row = 4, column = 0, columnspan= 2 ,pady=10)
        label5.grid(row = 5, column = 0, columnspan= 2 ,pady=10)
        label6.grid(row = 6, column = 0, columnspan= 2 ,pady=10)
        label7.grid(row = 7, column = 0, columnspan= 2 ,pady=10)
    
        label8.grid(row = 3, column = 2, columnspan= 2 ,pady=10)
        label9.grid(row = 4, column = 2, columnspan= 2 ,pady=10)
        label10.grid(row = 5, column = 2, columnspan= 2 ,pady=10)
        label11.grid(row = 6, column = 2, columnspan= 2 ,pady=10)
        label12.grid(row = 7, column = 2, columnspan= 2,pady=10 )
        
        my_but2= Button(root1, text='Store?',padx= 10,command=Update,fg='#2f3e46',bg='#FFFFFF')
        my_but2.grid(row=9,column = 0,columnspan = 2)
        my_but3= Button(root1, text='Next',padx= 10,fg='#2f3e46',bg='#FFFFFF',command=des)
        my_but3.grid(row=9,column = 2,columnspan = 2)
        
        
        root1.mainloop()
    

    def myClear():
        v1.delete(0,'end')
        v2.delete(0,'end')
        v3.delete(0,'end')
        v4.delete(0,'end')
        v5.delete(0,'end')
        v6.delete(0,'end')
        v7.delete(0,'end')
        v8.delete(0,'end')
        v9.delete(0,'end')
        v10.delete(0,'end')
        v11.delete(0,'end')
        v12.delete(0,'end')
        v13.delete(0,'end')
        v14.delete(0,'end')
        v15.delete(0,'end')
        v16.delete(0,'end')
        v17.delete(0,'end')
        
    root1.destroy()
    root=Tk()
    root.title("Variables input")
    root.geometry("455x730")
    root.configure(bg='#17202A')
    f1 = Label(root,text= "confirmed :",padx=50,fg='white',bg='#696969')
    f1.grid(row = 1, padx= 30,pady=10,column = 0)
    v1 = Entry(root,width = 30)
    v1.grid(row=1,padx= 15,column = 4)
    f2 = Label(root,text= "recovered :",padx=50,fg='white',bg='#696969')
    f2.grid(row = 2, pady=10,column = 0)
    v2 = Entry(root, width = 30)
    v2.grid(row=2,column = 4)
    f3 = Label(root,text= "deceased :",padx=50,fg='white',bg='#696969')
    f3.grid(row = 3, pady=10,column = 0)
    v3 = Entry(root, width = 30)
    v3.grid(row=3,column = 4)
    f4 = Label(root,text= "Vaccine_doses :",padx=36,fg='white',bg='#696969')
    f4.grid(row = 4, pady=10,column = 0)
    v4 = Entry(root, width = 30)
    v4.grid(row=4,column = 4)
    f5 = Label(root,text= "pop perc :",padx=50,fg='white',bg='#696969')
    f5.grid(row = 5, pady=10,column = 0)
    v5 = Entry(root, width = 30)
    v5.grid(row=5,column =4)
    f6 = Label(root,text= "Population :",padx=45,fg='white',bg='#696969')
    f6.grid(row = 6, pady=10,column = 0)
    v6 = Entry(root, width = 30)
    v6.grid(row=6,column = 4)
    f7 = Label(root,text= "pop_density :",padx=42,fg='white',bg='#696969')
    f7.grid(row = 7, pady=10,column = 0)
    v7 = Entry(root, width = 30)
    v7.grid(row=7,column = 4)
    f8 = Label(root,text= "Oxygen Production :",padx=23,fg='white',bg='#696969')
    f8.grid(row = 8, pady=10,column = 0)
    v8 = Entry(root, width = 30)
    v8.grid(row=8,column = 4)
    f9 = Label(root,text= "Demand :",padx=52,fg='white',bg='#696969')
    f9.grid(row = 9, pady=10,column = 0)
    v9 = Entry(root, width = 30)
    v9.grid(row=9,column = 4)
    f10 = Label(root,text= "Supply :",padx=55,fg='white',bg='#696969')
    f10.grid(row = 10, pady=10,column = 0)
    v10 = Entry(root, width = 30)
    v10.grid(row=10,column = 4)
    f11 = Label(root,text= "18-45yrs per :",padx=41,fg='white',bg='#696969')
    f11.grid(row = 11, pady=10,column = 0)
    v11 = Entry(root, width = 30)
    v11.grid(row=11,column = 4)
    f12 = Label(root,text= "45+yrs perr :",padx=44,fg='white',bg='#696969')
    f12.grid(row = 12, pady=10,column = 0)
    v12 = Entry(root, width = 30)
    v12.grid(row=12,column = 4)
    f13 = Label(root,text= "hospital :",padx=52,fg='white',bg='#696969')
    f13.grid(row = 13, pady=10,column = 0)
    v13 = Entry(root, width = 30)
    v13.grid(row=13,column = 4)
    f14 = Label(root,text= "beds :",padx=61,fg='white',bg='#696969')
    f14.grid(row = 14, pady=10,column = 0)
    v14 = Entry(root, width = 30)
    v14.grid(row=14,column = 4)
    f15 = Label(root,text= "Test Positivity Ratio :",padx=23,fg='white',bg='#696969')
    f15.grid(row = 15, pady=10,column = 0)
    v15 = Entry(root, width = 30)
    v15.grid(row=15,column = 4)
    f16 = Label(root,text= "Growth in TPR :",padx=37,fg='white',bg='#696969')
    f16.grid(row = 16, pady=10,column = 0)
    v16 = Entry(root, width = 30)
    v16.grid(row=16,pady=10,column = 4)
    f17 = Label(root,text= "Number of tests :",padx=32,fg='white',bg='#696969')
    f17.grid(row = 17, pady=10,column = 0)
    v17 = Entry(root, width = 30)
    v17.grid(row=17,column = 4)
    
    my_but= Button(root, text='Submit',padx= 10,command=mySubmit,fg='#2f3e46',bg='#FFFFFF')
    my_but.grid(row=19,column = 0,columnspan = 3)
    my_but1= Button(root, text='Clear',padx= 10,command=myClear,fg='#2f3e46',bg='#FFFFFF')
    my_but1.grid(row=19,column = 3,columnspan = 3)

# %%
def stats():
    
    def onClick():
        
        client = pymongo.MongoClient("mongodb://rk:Test12345@cluster0-shard-00-00.s0mpm.mongodb.net:27017,cluster0-shard-00-01.s0mpm.mongodb.net:27017,cluster0-shard-00-02.s0mpm.mongodb.net:27017/Sample?ssl=true&replicaSet=atlas-elkw9m-shard-0&authSource=admin&retryWrites=true&w=majority")
        db = client.test

        #client = pymongo.MongoClient(connection_url)
  
        # # Database
        Database = client.get_database('Sample')
        # # Table
        SampleTable1 = Database.covid
        queryObject = {'Name': "TS"}
        query = SampleTable1.find_one(queryObject)
        print(query['Name'],query['Confirmed'],query['Recovered'],query['Population'],query['Test positivity ratio'],query['Vaccine Doses'])
        
        root4= Toplevel(root3)
        root4.geometry("440x260")
        root4.title("stats")
        root4.configure(bg='#17202A')
        label1 = Label(root4, text="Name",padx=75,fg='white',bg='#696969')
        label2 = Label(root4, text="Confirmed",padx=63,fg='white',bg='#696969')
        label3 = Label(root4, text="Recovered",padx=65,fg='white',bg='#696969')
        label4 = Label(root4, text="Population",padx=65,fg='white',bg='#696969')
        label5 = Label(root4, text="Test Positivity Ratio",padx=43,fg='white',bg='#696969')
        label6 = Label(root4,text="Vaccine Doses",padx=57,fg='white',bg='#696969')
        
        label7 = Label(root4, text=query['Name'],padx=70,fg='white',bg='#696969')
        label8 = Label(root4, text=query['Confirmed'],padx=64,fg='white',bg='#696969')
        label9 = Label(root4, text=query['Recovered'],padx=64,fg='white',bg='#696969')
        label10 = Label(root4, text=query['Population'],padx=50,fg='white',bg='#696969')
        label11 = Label(root4, text=query['Test positivity ratio'],padx=73,fg='white',bg='#696969')
        label12 = Label(root4,text=query['Vaccine Doses'],padx=62,fg='white',bg='#696969')
        
        label1.grid(row = 1, column = 0, columnspan= 2 ,pady=10,padx=30)
        label2.grid(row = 2, column = 0, columnspan= 2 ,pady=10)
        label3.grid(row = 3, column = 0, columnspan= 2 ,pady=10)
        label4.grid(row = 4, column = 0, columnspan= 2 ,pady=10)
        label5.grid(row = 5, column = 0, columnspan= 2 ,pady=10)
        label6.grid(row = 6, column = 0, columnspan= 2 ,pady=10)
        
        label7.grid(row = 1, column = 2, columnspan= 2 ,pady=10)
        label8.grid(row = 2, column = 2, columnspan= 2 ,pady=10)
        label9.grid(row = 3, column = 2, columnspan= 2 ,pady=10)
        label10.grid(row = 4, column = 2, columnspan= 2 ,pady=10)
        label11.grid(row = 5, column = 2, columnspan= 2 ,pady=10)
        label12.grid(row = 6, column = 2, columnspan= 2 ,pady=10)
        
        root4.mainloop()
    
    root3 = Toplevel(root1)
    root3.title("stats")
    root3.geometry("1000x1000")
    im=Image.open("C:/Users/Rohit/Desktop/DSS_project/3.png")
    im=im.resize((1000,1000))
    img = ImageTk.PhotoImage(im)
    lab=Label(root3,image=img)
    lab.pack()
    button1=Button(root3, width=3,height=1,text="TS",command = onClick)
    
    button1.place(x=389, y=540)
    
    root3.mainloop()

# %%
root1 = Tk()
root1.title("Start up")
root1.geometry("500x350")
root1.configure(bg='#17202A')
#this creates 'Label' widget for Registration Form and uses place() method.
label_0 =Label(root1,text="Risk Weight Assessment", width=20,font=("bold",20),fg='#FFFFFF',bg='#696969')
#place method in tkinter is  geometry manager it is used to organize widgets by placing them in specific position
label_0.place(x=90,y=60)

my_but2= Button(root1, text='Calculate',padx=40,pady=7,command = calculate,fg='#FFFFFF',bg='#696969')
my_but2.place(x=90,y=250)
my_but3= Button(root1, text='View Stats',padx=40,pady=7,command = stats,fg='#FFFFFF',bg='#696969')
my_but3.place(x=280,y=250)

root1.mainloop()

# %%
86.00
25.00
1.00
171785.00
29.21
3103000.00
130.00
50.00
18.00
18.00
43.36
19.50
10.00
0.00
5.90
1.10
599801.00

# %%
import tkinter as tk
from tkinter import filedialog

root = tk.Tk()
root.withdraw()

file_path = filedialog.askopenfilenames()
print(file_path)
